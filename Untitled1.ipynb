# %%
import pandas as pd

# %%
D1=pd.read_csv("Electric_Vehicle_Population_Data.csv")
D1
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
D1.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  150479.000000  150482.000000   150482.000000  150482.000000
# mean    98168.344154    2020.005436       67.877839    1312.644735
# std      2473.612184       3.015209       96.230009    9231.310215
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       18.000000       0.000000
# 75%     98370.000000    2023.000000       97.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         150141.000000    1.504820e+05       1.504790e+05
# mean              29.343950    2.111122e+08       5.297195e+10
# std               14.824829    8.196388e+07       1.638841e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150482 entries, 0 to 150481
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150482 non-null  object
#  1   County                                             150479 non-null  object
#  2   City                                               150479 non-null  object
#  3   State                                              150482 non-null  object
#  4   Postal Code                                        150479 non-null  float64
#  5   Model Year                                         150482 non-null  int64
#  6   Make                                               150482 non-null  object
#  7   Model                                              150482 non-null  object
# ...

# %%
D1.shape
# Out:
# (150482, 17)

# %%
D1.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
D1.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
D1.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
D1.iloc[5000]
# Out:
# VIN (1-10)                                                                              1C4RJYD62N
# County                                                                                        King
# City                                                                                   Woodinville
# State                                                                                           WA
# Postal Code                                                                                98072.0
# Model Year                                                                                    2022
# Make                                                                                          JEEP
# Model                                                                               GRAND CHEROKEE
# Electric Vehicle Type                                       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
D1.iloc[4000]
# Out:
# VIN (1-10)                                                                                  KNDC3DLC2N
# County                                                                                            King
# City                                                                                            Duvall
# State                                                                                               WA
# Postal Code                                                                                    98019.0
# Model Year                                                                                        2022
# Make                                                                                               KIA
# Model                                                                                              EV6
# Electric Vehicle Type                                                   Battery Electric Vehicle (BEV)
# ...

# %%
D1.iloc[150476,6]
# Out:
# 'CHEVROLET'

# %%
D1.iloc[150476,7]
# Out:
# 'BOLT EV'

# %%
D1.iloc[150477,6]
# Out:
# 'BMW'

# %%
print(D1.loc[6,'Make'])
# Out:
# CHRYSLER

# %%
print(D1.loc[7,'Make'])
# Out:
# TESLA

# %%
D1.loc[2001,['Make','City']]
# Out:
# Make        KIA
# City    Olympia
# Name: 2001, dtype: object

# %%
D1[(D1['Model Year']>2020) & (D1['Electric Range']>200)]
# Out:
#         VIN (1-10)     County               City State  Postal Code  \
# 31      WA1LAAGE7M     Yakima             Yakima    WA      98908.0
# 527     LPSED3KA0M     Kitsap  Bainbridge Island    WA      98110.0
# 553     WA1AAAGEXM       King           Kirkland    WA      98034.0
# 1077    WP0AB2Y13M       King           Bellevue    WA      98004.0
# 1857    WP0AB2Y11M       King           Kirkland    WA      98033.0
# ...            ...        ...                ...   ...          ...
# 145186  LPSED3KA4M     Pierce         Gig Harbor    WA      98335.0
# 147033  WA1AAAGE7M  Snohomish            Bothell    WA      98021.0
# 147183  WA1AAAGE3M       King            Seattle    WA      98119.0
# 149563  LPSED3KA2M     Pierce           Puyallup    WA      98374.0
# 150383  WA12AAGE4M       King            Seattle    WA      98136.0
#
#         Model Year      Make             Model  \
# 31            2021      AUDI            E-TRON
# 527           2021  POLESTAR               PS2
# ...

# %%
import pandas as pd

# %%
D1=pd.read_csv("Electric_Vehicle_Population_Data.csv")
D1
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
D1.query("Make=='AUDI' and Model =='E-TRON'")
# Out:
#         VIN (1-10)     County         City State  Postal Code  Model Year  \
# 16      WA1VABGE4K       King      Seattle    WA      98112.0        2019
# 31      WA1LAAGE7M     Yakima       Yakima    WA      98908.0        2021
# 170     WA1LABGE8K  Snohomish      Bothell    WA      98012.0        2019
# 200     WA1VABGE6K  Snohomish      Woodway    WA      98020.0        2019
# 553     WA1AAAGEXM       King     Kirkland    WA      98034.0        2021
# ...            ...        ...          ...   ...          ...         ...
# 149770  WA1LAAGE5N  Snohomish     Lynnwood    WA      98036.0        2022
# 149795  WA1VAAGE5K    Spokane      Spokane    WA      99201.0        2019
# 149827  WA1VABGE0N     Pierce   Fox Island    WA      98333.0        2022
# 149937  WA1VABGE4K     Chelan  Leavenworth    WA      98826.0        2019
# 149950  WA1LAAGE1K     Pierce   Gig Harbor    WA      98332.0        2019
#
#         Make   Model           Electric Vehicle Type  \
# ...

# %%
D1.rename(columns ={'Electric Range': 'EleRa'}, inplace=True)

# %%
D1.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# EleRa                                                  0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
D1.drop(3,axis=0, inplace=True)

# %%
D1.sort_values(by='Model Year', ascending=False, inplace= True)
D1
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 9894    YV4H60CEXR       King       Seattle    WA      98115.0        2024
# 69972   JM3KKEHA8R       King       Seattle    WA      98118.0        2024
# 90471   1C4RJXP66R       King       Seattle    WA      98103.0        2024
# 116750  WA15AAGE2R       King       Seattle    WA      98105.0        2024
# 102027  5UX43EU04R  Snohomish     Snohomish    WA      98290.0        2024
# ...            ...        ...           ...   ...          ...         ...
# 125433  1FTZR0812X     Skagit  Mount Vernon    WA      98274.0        1999
# 134543  1FTZR0812X     Pierce        Graham    WA      98338.0        1999
# 144349  1FTZR0819X    Whatcom        Deming    WA      98244.0        1999
# 28068   1FTZR1078W    Clallam        Sequim    WA      98382.0        1998
# 138083  1GCDE14HXV  Snohomish    Marysville    WA      98270.0        1997
#
# ...

# %%
D1.groupby(['Make','Model'])['EleRa'].sum()
# Out:
# Make                  Model
# ALFA ROMEO            TONALE       396
# AUDI                  A3          9184
#                       A7           288
#                       A8 E          51
#                       E-TRON    120120
#                                  ...
# VOLVO                 V60          920
#                       XC40           0
#                       XC60       22895
#                       XC90       27470
# WHEEGO ELECTRIC CARS  WHEEGO       300
# Name: EleRa, Length: 127, dtype: int64
